# %% [markdown]
# # 과적합 피하기 - 초음파 광물 데이터

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## 데이터 전처리

# %%
from google.colab import files
up = files.upload()
filename = list(up.keys())[0]
# Out:
#      <input type="file" id="files-d6ec3955-5c03-4465-873c-239ec463cc70" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6ec3955-5c03-4465-873c-239ec463cc70">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sonar.csv to sonar (1).csv

# %%
df = pd.read_csv(filename, header=None)
df.head(3)
# Out:
#        0       1       2       3       4   ...      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
#
# [3 rows x 61 columns]

# %%
np.unique(df.values[:,-1], return_counts=True)
# Out:
# (array(['M', 'R'], dtype=object), array([111,  97]))

# %%
# X data: scaling
from sklearn.preprocessing import StandardScaler
X_scaled = StandardScaler().fit_transform(df.iloc[:,:-1].values)

# %%
# Y data: label encoding
from sklearn.preprocessing import LabelEncoder
y_labeled = LabelEncoder().fit_transform(df.iloc[:,-1].values)

# %%
np.array([0.1, 0.2, 'R']) # iloc를 하지 않고 values를 할 경우 문자열로 출력되기 때문
# Out:
# array(['0.1', '0.2', 'R'], dtype='<U32')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_labeled, stratify=y_labeled, test_size=0.2, random_state=seed
)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((166, 60), (42, 60), (166,), (42,))

# %% [markdown]
# ## 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ### 1. 은닉층 2개

# %%
model1 = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(12, activation='relu'),
    Dense(1, activation='sigmoid')
])
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                4880
#
#  dense_1 (Dense)             (None, 12)                972
#
#  dense_2 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 5,865
# Trainable params: 5,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
h1 = model1.fit(X_train, y_train, validation_split=.2, epochs=200, batch_size=50, verbose=0)
model1.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3529 - accuracy: 0.9048
# [0.3528617322444916, 0.9047619104385376]

# %% [markdown]
# ### 2. 은닉층: 4개

# %%
model2 = Sequential([
    Dense(64, input_dim=60, activation='relu'),
    Dense(30, activation='relu'),
    Dense(12, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                3904
#
#  dense_4 (Dense)             (None, 30)                1950
#
#  dense_5 (Dense)             (None, 12)                372
#
#  dense_6 (Dense)             (None, 4)                 52
#
#  dense_7 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 6,283
# Trainable params: 6,283
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 층의 개수를 늘린다고 무조건 결과가 좋아지는 것은 아님
model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
h2 = model2.fit(X_train, y_train, validation_split=.2, epochs=200, batch_size=50, verbose=0)
model2.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5415 - accuracy: 0.8095
# [0.5415384769439697, 0.8095238208770752]

# %% [markdown]
# ### 3. 은닉층: 6개

# %%
model3 = Sequential([
    Dense(64, input_dim=60, activation='relu'),
    Dense(40, activation='relu'),
    Dense(28, activation='relu'),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                3904
#
#  dense_9 (Dense)             (None, 40)                2600
#
#  dense_10 (Dense)            (None, 28)                1148
#
#  dense_11 (Dense)            (None, 16)                464
#
#  dense_12 (Dense)            (None, 8)                 136
#
#  dense_13 (Dense)            (None, 4)                 36
#
#  dense_14 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 8,293
# Trainable params: 8,293
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
h3 = model3.fit(X_train, y_train, validation_split=.2, epochs=200, batch_size=50, verbose=0)
model3.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5902 - accuracy: 0.8333
# [0.5901774168014526, 0.8333333134651184]

# %% [markdown]
# * model1을 그대로 사용하는데, epoch 횟수를 늘린다.

# %%
model = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(12, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 80)                4880
#
#  dense_16 (Dense)            (None, 12)                972
#
#  dense_17 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 5,865
# Trainable params: 5,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
hist = model.fit(X_train, y_train, validation_split=.2, epochs=1000, batch_size=50, verbose=0)
model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6320 - accuracy: 0.8571
# [0.6319936513900757, 0.8571428656578064]

# %%
import matplotlib.pyplot as plt

y_acc = hist.history['accuracy'][:100]
y_vloss = hist.history['val_loss'][:100]
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, ms=5, label='train accuracy')
plt.plot(xs, y_vloss, ms=5, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# ## 모델 저장조건 설정

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
import os
if not os.path.exists('model'):
    os.mkdir('model')

# %%
model_path = 'model/sonar.h5'
checkpoint = ModelCheckpoint(
    model_path, monitor='val_loss', verbose=1, save_best_only=True
)

# %%
model = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(12, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 80)                4880
#
#  dense_19 (Dense)            (None, 12)                972
#
#  dense_20 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 5,865
# Trainable params: 5,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
hist = model.fit(
    X_train, y_train, validation_split=0.2,
    epochs=400, batch_size=50, verbose=0,
    callbacks=[checkpoint]
)

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, ms=5, label='train accuracy')
plt.plot(xs, y_vloss, ms=5, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()

# %%
from tensorflow.keras.models import load_model
best_model = load_model(model_path)
best_model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3861 - accuracy: 0.8571
# [0.3861370086669922, 0.8571428656578064]

# %% [markdown]
# ## 조기 종료시점 설정

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(patience=30)

# %%
model = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(12, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 80)                4880
#
#  dense_25 (Dense)            (None, 12)                972
#
#  dense_26 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 5,865
# Trainable params: 5,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
hist = model.fit(
    X_train, y_train, validation_split=0.2,
    epochs=400, batch_size=50, verbose=1,
    callbacks=[checkpoint, early_stopping]
)

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, ms=5, label='train accuracy')
plt.plot(xs, y_vloss, ms=5, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
