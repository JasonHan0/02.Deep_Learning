# %% [markdown]
# # Titanic Data Binary Classification Accuracy | 타이타닉 데이터 이진 분류 정확도

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import tensorflow as tf
seed = 2021
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## 데이터 전처리

# %%
df = sns.load_dataset('titanic')
df.head(3)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
#
# [3 rows x 15 columns]

# %%
# 결측치 확인
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()

# %%
# 이진분류 어려운 데이터 드랍
df.drop(['class','who','deck','embark_town','alive'], axis=1, inplace=True)

# %%
df.head(3)
# Out:
#    survived  pclass     sex   age  ...     fare  embarked  adult_male  alone
# 1         1       1  female  38.0  ...  71.2833         C       False  False
# 3         1       1  female  35.0  ...  53.1000         S       False  False
# 6         0       1    male  54.0  ...  51.8625         S        True   True
#
# [3 rows x 10 columns]

# %%
# 카테고리형 데이터 cat.codes로 변환
df['sex'] = df['sex'].astype('category').cat.codes
df['embarked'] = df['embarked'].astype('category').cat.codes
df['adult_male'] = df['adult_male'].astype('category').cat.codes
df['alone'] = df['alone'].astype('category').cat.codes

# one-hot 인코딩을 위한 get_dummies 사용
df['pclass'] = pd.get_dummies(df['pclass'])

# 가족 단위 수 group_num을 만들어 새로운 열로 추가
df['group_num'] = df['sibsp'] + df['parch'] + 1

# %%
df.head(3)
# Out:
#    survived  pclass  sex   age  ...  embarked  adult_male  alone  group_num
# 1         1       1    0  38.0  ...         0           0      0          2
# 3         1       1    0  35.0  ...         2           0      0          2
# 6         0       1    1  54.0  ...         2           1      1          1
#
# [3 rows x 11 columns]

# %%
np.unique(df.values[:,0], return_counts=True)  # 생존자 123, 사망자 59
# Out:
# (array([0., 1.]), array([ 59, 123]))

# %%
df.iloc[:, 1:]
# Out:
#      pclass  sex   age  sibsp  ...  embarked  adult_male  alone  group_num
# 1         1    0  38.0      1  ...         0           0      0          2
# 3         1    0  35.0      1  ...         2           0      0          2
# 6         1    1  54.0      0  ...         2           1      1          1
# 10        0    0   4.0      1  ...         2           0      0          3
# 11        1    0  58.0      0  ...         2           0      1          1
# ..      ...  ...   ...    ...  ...       ...         ...    ...        ...
# 871       1    0  47.0      1  ...         2           0      0          3
# 872       1    1  33.0      0  ...         2           1      1          1
# 879       1    0  56.0      0  ...         0           0      0          2
# 887       1    0  19.0      0  ...         2           0      1          1
# 889       1    1  26.0      0  ...         0           1      1          1
#
# [182 rows x 10 columns]

# %%
# 데이터 값의 단위가 상이하므로 정규화 수행
from sklearn.preprocessing import StandardScaler
X_scaled = StandardScaler().fit_transform(df.values[:,1:])
X_scaled
# Out:
# array([[ 0.39904344, -1.03352882,  0.15208196, ..., -0.9569689 ,
#         -0.8660254 ,  0.04958766],
#        [ 0.39904344, -1.03352882, -0.03987502, ..., -0.9569689 ,
#         -0.8660254 ,  0.04958766],
#        [ 0.39904344,  0.96755889,  1.17585249, ...,  1.04496604,
#          1.15470054, -0.85290771],
#        ...,
#        [ 0.39904344, -1.03352882,  1.30382381, ..., -0.9569689 ,
#         -0.8660254 ,  0.04958766],
#        [ 0.39904344, -1.03352882, -1.06364555, ..., -0.9569689 ,
#          1.15470054, -0.85290771],
#        [ 0.39904344,  0.96755889, -0.61574594, ...,  1.04496604,
#          1.15470054, -0.85290771]])

# %%
y = df.survived
y
# Out:
# 1      1
# 3      1
# 6      0
# 10     1
# 11     1
#       ..
# 871    1
# 872    0
# 879    1
# 887    1
# 889    1
# Name: survived, Length: 182, dtype: int64

# %% [markdown]
# ## 모델 정의/설정

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, stratify=y, random_state=seed, test_size=0.2
)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((145, 10), (37, 10), (145,), (37,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([
    Dense(32, input_dim=10, activation='relu'),
    Dense(32, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 32)                352
#
#  dense_11 (Dense)            (None, 32)                1056
#
#  dense_12 (Dense)            (None, 4)                 132
#
#  dense_13 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 1,545
# Trainable params: 1,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']
)

# %% [markdown]
# ## 모델 저장관련 설정

# %%
import os
if not os.path.exists('model'):
    os.mkdir('model')

# %%
model_path = 'model/titanic.h5'

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(
    model_path, monitor='val_loss', verbose=1, save_best_only=True
)

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(patience=100)

# %% [markdown]
# ## 모델 학습 및 저장

# %%
hist = model.fit(
    X_train, y_train, validation_split=0.2, verbose=0,
    epochs=100, batch_size=50, callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 00001: val_loss improved from inf to 0.70219, saving model to model/titanic.h5
#
# Epoch 00002: val_loss improved from 0.70219 to 0.69377, saving model to model/titanic.h5
#
# Epoch 00003: val_loss improved from 0.69377 to 0.68611, saving model to model/titanic.h5
#
# Epoch 00004: val_loss improved from 0.68611 to 0.67941, saving model to model/titanic.h5
#
# Epoch 00005: val_loss improved from 0.67941 to 0.67221, saving model to model/titanic.h5
#
# Epoch 00006: val_loss improved from 0.67221 to 0.66396, saving model to model/titanic.h5
#
# Epoch 00007: val_loss improved from 0.66396 to 0.65484, saving model to model/titanic.h5
#
# Epoch 00008: val_loss improved from 0.65484 to 0.64606, saving model to model/titanic.h5
#
# Epoch 00009: val_loss improved from 0.64606 to 0.63694, saving model to model/titanic.h5
#
# Epoch 00010: val_loss improved from 0.63694 to 0.62774, saving model to model/titanic.h5
#
# Epoch 00011: val_loss improved from 0.62774 to 0.61831, saving model to model/titanic.h5
#
# Epoch 00012: val_loss improved from 0.61831 to 0.60852, saving model to model/titanic.h5
#
# Epoch 00013: val_loss improved from 0.60852 to 0.59854, saving model to model/titanic.h5
#
# Epoch 00014: val_loss improved from 0.59854 to 0.58840, saving model to model/titanic.h5
#
# Epoch 00015: val_loss improved from 0.58840 to 0.57782, saving model to model/titanic.h5
#
# Epoch 00016: val_loss improved from 0.57782 to 0.56685, saving model to model/titanic.h5
#
# Epoch 00017: val_loss improved from 0.56685 to 0.55566, saving model to model/titanic.h5
#
# Epoch 00018: val_loss improved from 0.55566 to 0.54475, saving model to model/titanic.h5
#
# Epoch 00019: val_loss improved from 0.54475 to 0.53385, saving model to model/titanic.h5
#
# Epoch 00020: val_loss improved from 0.53385 to 0.52305, saving model to model/titanic.h5
#
# Epoch 00021: val_loss improved from 0.52305 to 0.51237, saving model to model/titanic.h5
#
# Epoch 00022: val_loss improved from 0.51237 to 0.50143, saving model to model/titanic.h5
#
# Epoch 00023: val_loss improved from 0.50143 to 0.49025, saving model to model/titanic.h5
#
# Epoch 00024: val_loss improved from 0.49025 to 0.47922, saving model to model/titanic.h5
#
# Epoch 00025: val_loss improved from 0.47922 to 0.46887, saving model to model/titanic.h5
#
# Epoch 00026: val_loss improved from 0.46887 to 0.45945, saving model to model/titanic.h5
#
# Epoch 00027: val_loss improved from 0.45945 to 0.45032, saving model to model/titanic.h5
#
# Epoch 00028: val_loss improved from 0.45032 to 0.44084, saving model to model/titanic.h5
#
# Epoch 00029: val_loss improved from 0.44084 to 0.43119, saving model to model/titanic.h5
#
# Epoch 00030: val_loss improved from 0.43119 to 0.42236, saving model to model/titanic.h5
#
# Epoch 00031: val_loss improved from 0.42236 to 0.41495, saving model to model/titanic.h5
#
# Epoch 00032: val_loss improved from 0.41495 to 0.40776, saving model to model/titanic.h5
#
# Epoch 00033: val_loss improved from 0.40776 to 0.40015, saving model to model/titanic.h5
#
# Epoch 00034: val_loss improved from 0.40015 to 0.39251, saving model to model/titanic.h5
#
# Epoch 00035: val_loss improved from 0.39251 to 0.38506, saving model to model/titanic.h5
#
# Epoch 00036: val_loss improved from 0.38506 to 0.37947, saving model to model/titanic.h5
#
# Epoch 00037: val_loss improved from 0.37947 to 0.37539, saving model to model/titanic.h5
#
# Epoch 00038: val_loss improved from 0.37539 to 0.37089, saving model to model/titanic.h5
#
# Epoch 00039: val_loss improved from 0.37089 to 0.36575, saving model to model/titanic.h5
#
# Epoch 00040: val_loss improved from 0.36575 to 0.36062, saving model to model/titanic.h5
#
# Epoch 00041: val_loss improved from 0.36062 to 0.35551, saving model to model/titanic.h5
#
# Epoch 00042: val_loss improved from 0.35551 to 0.35150, saving model to model/titanic.h5
#
# Epoch 00043: val_loss improved from 0.35150 to 0.34755, saving model to model/titanic.h5
#
# Epoch 00044: val_loss improved from 0.34755 to 0.34562, saving model to model/titanic.h5
#
# Epoch 00045: val_loss improved from 0.34562 to 0.34412, saving model to model/titanic.h5
#
# Epoch 00046: val_loss improved from 0.34412 to 0.34189, saving model to model/titanic.h5
#
# Epoch 00047: val_loss improved from 0.34189 to 0.33868, saving model to model/titanic.h5
#
# Epoch 00048: val_loss improved from 0.33868 to 0.33659, saving model to model/titanic.h5
#
# Epoch 00049: val_loss improved from 0.33659 to 0.33425, saving model to model/titanic.h5
#
# Epoch 00050: val_loss improved from 0.33425 to 0.33234, saving model to model/titanic.h5
#
# Epoch 00051: val_loss improved from 0.33234 to 0.33169, saving model to model/titanic.h5
#
# Epoch 00052: val_loss improved from 0.33169 to 0.33140, saving model to model/titanic.h5
#
# Epoch 00053: val_loss improved from 0.33140 to 0.33038, saving model to model/titanic.h5
#
# Epoch 00054: val_loss improved from 0.33038 to 0.32852, saving model to model/titanic.h5
#
# Epoch 00055: val_loss improved from 0.32852 to 0.32557, saving model to model/titanic.h5
#
# Epoch 00056: val_loss improved from 0.32557 to 0.32316, saving model to model/titanic.h5
#
# Epoch 00057: val_loss improved from 0.32316 to 0.32141, saving model to model/titanic.h5
#
# Epoch 00058: val_loss improved from 0.32141 to 0.32092, saving model to model/titanic.h5
#
# Epoch 00059: val_loss improved from 0.32092 to 0.32047, saving model to model/titanic.h5
#
# Epoch 00060: val_loss improved from 0.32047 to 0.31856, saving model to model/titanic.h5
#
# Epoch 00061: val_loss improved from 0.31856 to 0.31757, saving model to model/titanic.h5
#
# Epoch 00062: val_loss improved from 0.31757 to 0.31615, saving model to model/titanic.h5
#
# Epoch 00063: val_loss improved from 0.31615 to 0.31477, saving model to model/titanic.h5
#
# Epoch 00064: val_loss improved from 0.31477 to 0.31455, saving model to model/titanic.h5
#
# Epoch 00065: val_loss improved from 0.31455 to 0.31431, saving model to model/titanic.h5
#
# Epoch 00066: val_loss improved from 0.31431 to 0.31364, saving model to model/titanic.h5
#
# Epoch 00067: val_loss did not improve from 0.31364
#
# Epoch 00068: val_loss did not improve from 0.31364
#
# Epoch 00069: val_loss did not improve from 0.31364
#
# Epoch 00070: val_loss did not improve from 0.31364
#
# Epoch 00071: val_loss improved from 0.31364 to 0.31344, saving model to model/titanic.h5
#
# Epoch 00072: val_loss improved from 0.31344 to 0.31211, saving model to model/titanic.h5
#
# Epoch 00073: val_loss improved from 0.31211 to 0.31130, saving model to model/titanic.h5
#
# Epoch 00074: val_loss improved from 0.31130 to 0.31059, saving model to model/titanic.h5
#
# Epoch 00075: val_loss improved from 0.31059 to 0.30966, saving model to model/titanic.h5
#
# Epoch 00076: val_loss improved from 0.30966 to 0.30942, saving model to model/titanic.h5
#
# Epoch 00077: val_loss did not improve from 0.30942
#
# Epoch 00078: val_loss did not improve from 0.30942
#
# Epoch 00079: val_loss did not improve from 0.30942
#
# Epoch 00080: val_loss did not improve from 0.30942
#
# Epoch 00081: val_loss did not improve from 0.30942
#
# Epoch 00082: val_loss did not improve from 0.30942
#
# Epoch 00083: val_loss did not improve from 0.30942
#
# Epoch 00084: val_loss improved from 0.30942 to 0.30807, saving model to model/titanic.h5
#
# Epoch 00085: val_loss improved from 0.30807 to 0.30665, saving model to model/titanic.h5
#
# Epoch 00086: val_loss improved from 0.30665 to 0.30522, saving model to model/titanic.h5
#
# Epoch 00087: val_loss improved from 0.30522 to 0.30403, saving model to model/titanic.h5
#
# Epoch 00088: val_loss improved from 0.30403 to 0.30355, saving model to model/titanic.h5
#
# Epoch 00089: val_loss improved from 0.30355 to 0.30349, saving model to model/titanic.h5
#
# Epoch 00090: val_loss did not improve from 0.30349
#
# Epoch 00091: val_loss did not improve from 0.30349
#
# Epoch 00092: val_loss did not improve from 0.30349
#
# Epoch 00093: val_loss did not improve from 0.30349
#
# Epoch 00094: val_loss did not improve from 0.30349
#
# Epoch 00095: val_loss did not improve from 0.30349
#
# Epoch 00096: val_loss did not improve from 0.30349
#
# Epoch 00097: val_loss did not improve from 0.30349
#
# Epoch 00098: val_loss did not improve from 0.30349
#
# Epoch 00099: val_loss did not improve from 0.30349
#
# Epoch 00100: val_loss did not improve from 0.30349

# %% [markdown]
# ## 평가 - 베스트 모델

# %%
from tensorflow.keras.models import load_model
best_model=load_model(model_path)
best_model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4617 - accuracy: 0.7568
# [0.4617364704608917, 0.7567567825317383]
