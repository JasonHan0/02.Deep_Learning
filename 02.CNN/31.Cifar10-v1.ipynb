# %% [markdown]
# # Cifar-10 이미지 분류 v1

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1), (10000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 2))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i, 0]], fontsize=8)
plt.show()

# %%
# X data: 0~1 사이의 실수 (float32)로 변환
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype(np.float32) / 255.

# %%
# y_data: one-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)
Y_train.shape, Y_test.shape
# Out:
# ((50000, 10), (10000, 10))

# %% [markdown]
# ## 모델 정의/설정/학습

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([
    Conv2D(32, (3, 3), padding='same', input_shape=(32, 32, 3), activation='relu'),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3, 3), padding='same', activation='relu'),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
model_path = 'best-cifar10-v1.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2,
    epochs=100, batch_size=32, verbose=2,
    callbacks = [checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.57737, saving model to best-cifar10-v1.h5
# 1250/1250 - 17s - loss: 1.8292 - accuracy: 0.3287 - val_loss: 1.5774 - val_accuracy: 0.4264 - 17s/epoch - 14ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.57737 to 1.38022, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 1.5201 - accuracy: 0.4424 - val_loss: 1.3802 - val_accuracy: 0.5047 - 6s/epoch - 5ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.38022 to 1.27116, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 1.3921 - accuracy: 0.4958 - val_loss: 1.2712 - val_accuracy: 0.5528 - 6s/epoch - 5ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.27116 to 1.23826, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 1.2960 - accuracy: 0.5362 - val_loss: 1.2383 - val_accuracy: 0.5549 - 6s/epoch - 5ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.23826 to 1.20852, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 1.2159 - accuracy: 0.5679 - val_loss: 1.2085 - val_accuracy: 0.5804 - 7s/epoch - 5ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.20852 to 1.06009, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 1.1545 - accuracy: 0.5913 - val_loss: 1.0601 - val_accuracy: 0.6317 - 6s/epoch - 5ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss did not improve from 1.06009
# 1250/1250 - 7s - loss: 1.1018 - accuracy: 0.6161 - val_loss: 1.0782 - val_accuracy: 0.6185 - 7s/epoch - 5ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.06009 to 0.98262, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 1.0573 - accuracy: 0.6290 - val_loss: 0.9826 - val_accuracy: 0.6540 - 7s/epoch - 5ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.98262 to 0.97215, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 1.0164 - accuracy: 0.6451 - val_loss: 0.9722 - val_accuracy: 0.6601 - 7s/epoch - 5ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 0.97215
# 1250/1250 - 6s - loss: 0.9819 - accuracy: 0.6559 - val_loss: 0.9885 - val_accuracy: 0.6516 - 6s/epoch - 5ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.97215 to 0.88586, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.9525 - accuracy: 0.6687 - val_loss: 0.8859 - val_accuracy: 0.6909 - 7s/epoch - 5ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.88586 to 0.87573, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.9266 - accuracy: 0.6757 - val_loss: 0.8757 - val_accuracy: 0.6932 - 6s/epoch - 5ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 0.87573
# 1250/1250 - 7s - loss: 0.9012 - accuracy: 0.6860 - val_loss: 0.8875 - val_accuracy: 0.6872 - 7s/epoch - 5ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.87573 to 0.83280, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.8805 - accuracy: 0.6946 - val_loss: 0.8328 - val_accuracy: 0.7081 - 6s/epoch - 5ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.83280
# 1250/1250 - 7s - loss: 0.8574 - accuracy: 0.7036 - val_loss: 0.8357 - val_accuracy: 0.7064 - 7s/epoch - 5ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.83280 to 0.81871, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.8417 - accuracy: 0.7075 - val_loss: 0.8187 - val_accuracy: 0.7145 - 7s/epoch - 5ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.81871 to 0.78808, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.8264 - accuracy: 0.7128 - val_loss: 0.7881 - val_accuracy: 0.7236 - 6s/epoch - 5ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.78808 to 0.77834, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.8078 - accuracy: 0.7213 - val_loss: 0.7783 - val_accuracy: 0.7284 - 7s/epoch - 5ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 0.77834 to 0.77529, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.7983 - accuracy: 0.7240 - val_loss: 0.7753 - val_accuracy: 0.7309 - 7s/epoch - 5ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.77529 to 0.76967, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.7856 - accuracy: 0.7314 - val_loss: 0.7697 - val_accuracy: 0.7341 - 6s/epoch - 5ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.76967 to 0.76498, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.7743 - accuracy: 0.7342 - val_loss: 0.7650 - val_accuracy: 0.7365 - 7s/epoch - 5ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.76498
# 1250/1250 - 6s - loss: 0.7647 - accuracy: 0.7350 - val_loss: 0.7755 - val_accuracy: 0.7337 - 6s/epoch - 5ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.76498 to 0.74756, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.7552 - accuracy: 0.7407 - val_loss: 0.7476 - val_accuracy: 0.7436 - 6s/epoch - 5ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss improved from 0.74756 to 0.73364, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.7392 - accuracy: 0.7452 - val_loss: 0.7336 - val_accuracy: 0.7487 - 6s/epoch - 5ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.73364 to 0.73034, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.7391 - accuracy: 0.7456 - val_loss: 0.7303 - val_accuracy: 0.7494 - 6s/epoch - 5ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.73034 to 0.72283, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.7284 - accuracy: 0.7506 - val_loss: 0.7228 - val_accuracy: 0.7527 - 7s/epoch - 5ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 0.72283 to 0.71150, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.7264 - accuracy: 0.7528 - val_loss: 0.7115 - val_accuracy: 0.7564 - 6s/epoch - 5ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.71150
# 1250/1250 - 6s - loss: 0.7177 - accuracy: 0.7552 - val_loss: 0.7177 - val_accuracy: 0.7516 - 6s/epoch - 5ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss improved from 0.71150 to 0.70118, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.7150 - accuracy: 0.7573 - val_loss: 0.7012 - val_accuracy: 0.7594 - 6s/epoch - 5ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.70118
# 1250/1250 - 6s - loss: 0.7087 - accuracy: 0.7581 - val_loss: 0.7072 - val_accuracy: 0.7609 - 6s/epoch - 5ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.70118
# 1250/1250 - 7s - loss: 0.7028 - accuracy: 0.7612 - val_loss: 0.7016 - val_accuracy: 0.7601 - 7s/epoch - 5ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.70118
# 1250/1250 - 6s - loss: 0.7008 - accuracy: 0.7603 - val_loss: 0.7204 - val_accuracy: 0.7549 - 6s/epoch - 5ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss improved from 0.70118 to 0.69106, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.6901 - accuracy: 0.7653 - val_loss: 0.6911 - val_accuracy: 0.7624 - 7s/epoch - 5ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.69106
# 1250/1250 - 7s - loss: 0.6866 - accuracy: 0.7668 - val_loss: 0.6962 - val_accuracy: 0.7643 - 7s/epoch - 5ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.69106
# 1250/1250 - 7s - loss: 0.6821 - accuracy: 0.7679 - val_loss: 0.7404 - val_accuracy: 0.7548 - 7s/epoch - 5ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.69106
# 1250/1250 - 7s - loss: 0.6850 - accuracy: 0.7675 - val_loss: 0.7044 - val_accuracy: 0.7622 - 7s/epoch - 5ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.69106
# 1250/1250 - 6s - loss: 0.6797 - accuracy: 0.7698 - val_loss: 0.6970 - val_accuracy: 0.7600 - 6s/epoch - 5ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.69106
# 1250/1250 - 6s - loss: 0.6766 - accuracy: 0.7712 - val_loss: 0.6912 - val_accuracy: 0.7650 - 6s/epoch - 5ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.69106
# 1250/1250 - 7s - loss: 0.6686 - accuracy: 0.7736 - val_loss: 0.6950 - val_accuracy: 0.7619 - 7s/epoch - 5ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.69106
# 1250/1250 - 7s - loss: 0.6661 - accuracy: 0.7765 - val_loss: 0.7068 - val_accuracy: 0.7617 - 7s/epoch - 5ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss improved from 0.69106 to 0.67642, saving model to best-cifar10-v1.h5
# 1250/1250 - 7s - loss: 0.6628 - accuracy: 0.7742 - val_loss: 0.6764 - val_accuracy: 0.7709 - 7s/epoch - 5ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.67642
# 1250/1250 - 6s - loss: 0.6607 - accuracy: 0.7781 - val_loss: 0.6846 - val_accuracy: 0.7708 - 6s/epoch - 5ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 0.67642 to 0.65701, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.6507 - accuracy: 0.7821 - val_loss: 0.6570 - val_accuracy: 0.7796 - 6s/epoch - 5ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.65701
# 1250/1250 - 7s - loss: 0.6562 - accuracy: 0.7780 - val_loss: 0.6813 - val_accuracy: 0.7704 - 7s/epoch - 5ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.65701
# 1250/1250 - 6s - loss: 0.6549 - accuracy: 0.7796 - val_loss: 0.6811 - val_accuracy: 0.7747 - 6s/epoch - 5ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.65701
# 1250/1250 - 6s - loss: 0.6479 - accuracy: 0.7799 - val_loss: 0.6838 - val_accuracy: 0.7709 - 6s/epoch - 5ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss improved from 0.65701 to 0.65239, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.6488 - accuracy: 0.7836 - val_loss: 0.6524 - val_accuracy: 0.7790 - 6s/epoch - 5ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.65239
# 1250/1250 - 7s - loss: 0.6402 - accuracy: 0.7836 - val_loss: 0.6586 - val_accuracy: 0.7808 - 7s/epoch - 5ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.65239
# 1250/1250 - 6s - loss: 0.6415 - accuracy: 0.7846 - val_loss: 0.6635 - val_accuracy: 0.7764 - 6s/epoch - 5ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.65239
# 1250/1250 - 7s - loss: 0.6363 - accuracy: 0.7851 - val_loss: 0.6896 - val_accuracy: 0.7694 - 7s/epoch - 5ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 0.65239
# 1250/1250 - 7s - loss: 0.6273 - accuracy: 0.7868 - val_loss: 0.6544 - val_accuracy: 0.7802 - 7s/epoch - 5ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.65239
# 1250/1250 - 7s - loss: 0.6365 - accuracy: 0.7868 - val_loss: 0.6743 - val_accuracy: 0.7711 - 7s/epoch - 5ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss improved from 0.65239 to 0.64852, saving model to best-cifar10-v1.h5
# 1250/1250 - 6s - loss: 0.6274 - accuracy: 0.7898 - val_loss: 0.6485 - val_accuracy: 0.7781 - 6s/epoch - 5ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.64852
# 1250/1250 - 7s - loss: 0.6329 - accuracy: 0.7886 - val_loss: 0.6653 - val_accuracy: 0.7767 - 7s/epoch - 5ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.64852
# 1250/1250 - 6s - loss: 0.6241 - accuracy: 0.7891 - val_loss: 0.6813 - val_accuracy: 0.7777 - 6s/epoch - 5ms/step
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.64852
# 1250/1250 - 7s - loss: 0.6280 - accuracy: 0.7902 - val_loss: 0.6646 - val_accuracy: 0.7794 - 7s/epoch - 5ms/step
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.64852
# 1250/1250 - 7s - loss: 0.6234 - accuracy: 0.7917 - val_loss: 0.6660 - val_accuracy: 0.7832 - 7s/epoch - 5ms/step
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.64852
# 1250/1250 - 7s - loss: 0.6225 - accuracy: 0.7918 - val_loss: 0.6894 - val_accuracy: 0.7700 - 7s/epoch - 5ms/step
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.64852
# 1250/1250 - 6s - loss: 0.6171 - accuracy: 0.7932 - val_loss: 0.6750 - val_accuracy: 0.7762 - 6s/epoch - 5ms/step
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.64852
# 1250/1250 - 7s - loss: 0.6168 - accuracy: 0.7919 - val_loss: 0.6767 - val_accuracy: 0.7758 - 7s/epoch - 5ms/step
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.64852
# 1250/1250 - 6s - loss: 0.6190 - accuracy: 0.7936 - val_loss: 0.6713 - val_accuracy: 0.7795 - 6s/epoch - 5ms/step
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.64852
# 1250/1250 - 6s - loss: 0.6109 - accuracy: 0.7943 - val_loss: 0.6709 - val_accuracy: 0.7763 - 6s/epoch - 5ms/step
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 0.64852
# 1250/1250 - 7s - loss: 0.6174 - accuracy: 0.7937 - val_loss: 0.6777 - val_accuracy: 0.7712 - 7s/epoch - 5ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6662 - accuracy: 0.7801
# [0.6662166714668274, 0.7800999879837036]

# %% [markdown]
# ## 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
