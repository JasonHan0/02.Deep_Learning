# %% [markdown]
# # 고양이, 개 분류 - CNN v3
# - Dropout 추가
# - Kaggle에서 'Copy API Command'를 사용하여 API Key를 발급받을 것
# - Full Data로 수행

# %% [markdown]
# - 데이터 다운로드 및 압축 해제, 훈련/테스트 데이터 분리

# %%
from google.colab import files
up = files.upload()
# Out:
#      <input type="file" id="files-f32a7356-91ca-4d06-b850-19412542dbbe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f32a7356-91ca-4d06-b850-19412542dbbe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json

# %%
import json, os
with open('kaggle.json') as f:
    kaggle = json.load(f)
os.environ['KAGGLE_USERNAME'] = kaggle['username']    # username from the json file
os.environ['KAGGLE_KEY'] = kaggle['key']       # key from the json file

# %%
# !kaggle datasets download -d shaunthesheep/microsoft-catsvsdogs-dataset
# Out:
# microsoft-catsvsdogs-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip microsoft-catsvsdogs-dataset.zip > /dev/null
# Out:
# replace MSR-LA - 3467.docx? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
cat_dir = 'PetImages/Cat'
os.unlink(f'{cat_dir}/Thumbs.db')
cat_list = os.listdir(cat_dir)
len(cat_list)
# Out:
# 12500

# %%
dog_dir = 'PetImages/Dog'
os.unlink(f'{dog_dir}/Thumbs.db')
dog_list = os.listdir(dog_dir)
len(dog_list)
# Out:
# 12500

# %%
train_dir = 'PetImages/train'
test_dir = 'PetImages/test'
train_cats_dir = f'{train_dir}/cats'
train_dogs_dir = f'{train_dir}/dogs'
test_cats_dir = f'{test_dir}/cats'
test_dogs_dir = f'{test_dir}/dogs'

# %%
for dir_name in [train_dir,test_dir,train_cats_dir,train_dogs_dir,test_cats_dir,test_dogs_dir]:
    if not os.path.exists(dir_name):
        os.mkdir(dir_name)

# %%
for file in cat_list:
    if len(file) < 9:           # train data(0 ~ 9999)
        os.rename(f'{cat_dir}/{file}', f'{train_cats_dir}/{file}')
    else:                       # test data(10000 ~ 12499)
        os.rename(f'{cat_dir}/{file}', f'{test_cats_dir}/{file}')

# %%
len(os.listdir(cat_dir)), len(os.listdir(train_cats_dir)), len(os.listdir(test_cats_dir))
# Out:
# (0, 10000, 2500)

# %%
for file in dog_list:
    if len(file) < 9:           # train data
        os.rename(f'{dog_dir}/{file}', f'{train_dogs_dir}/{file}')
    else:                       # test data
        os.rename(f'{dog_dir}/{file}', f'{test_dogs_dir}/{file}')

# %%
len(os.listdir(dog_dir)), len(os.listdir(train_dogs_dir)), len(os.listdir(test_dogs_dir))
# Out:
# (0, 10000, 2500)

# %%
os.rmdir(cat_dir)
os.rmdir(dog_dir)

# %% [markdown]
# - 데이터 탐색

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# 파일 이름
test_cats_fnames = os.listdir(test_cats_dir)
test_dogs_fnames = os.listdir(test_dogs_dir)

print(test_cats_fnames[:5])
print(test_dogs_fnames[:5])
# Out:
# ['10851.jpg', '11613.jpg', '10898.jpg', '11350.jpg', '12122.jpg']
# ['10851.jpg', '11613.jpg', '10898.jpg', '11350.jpg', '12122.jpg']

# %%
# 파일 갯수
train_cats_fnames = os.listdir(train_cats_dir)
train_dogs_fnames = os.listdir(train_dogs_dir)
len(train_cats_fnames), len(train_dogs_fnames)
# Out:
# (10000, 10000)

# %%
# 666.jpg 이미지에 에러가 있어, 12000.jpg 파일로 대체
# !cp PetImages/test/cats/12000.jpg PetImages/train/cats/666.jpg

# %%
# 11702.jpg 이미지에 에러가 있어, 12000.jpg 파일로 대체
# !cp PetImages/test/dogs/10000.jpg PetImages/test/dogs/11702.jpg

# %% [markdown]
# - 모델 구성

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
# del model

# %%
model = Sequential([
    Conv2D(16, kernel_size=(3,3), input_shape=(150,150,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(32, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 148, 148, 16)      448
#
#  max_pooling2d_12 (MaxPoolin  (None, 74, 74, 16)       0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 74, 74, 16)        0
#
#  conv2d_13 (Conv2D)          (None, 72, 72, 32)        4640
#
#  max_pooling2d_13 (MaxPoolin  (None, 36, 36, 32)       0
#  g2D)
#
#  dropout_17 (Dropout)        (None, 36, 36, 32)        0
#
#  conv2d_14 (Conv2D)          (None, 34, 34, 64)        18496
#
#  max_pooling2d_14 (MaxPoolin  (None, 17, 17, 64)       0
#  g2D)
#
#  dropout_18 (Dropout)        (None, 17, 17, 64)        0
#
#  flatten_4 (Flatten)         (None, 18496)             0
#
#  dense_8 (Dense)             (None, 512)               9470464
#
#  dropout_19 (Dropout)        (None, 512)               0
#
#  dense_9 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - 모델 설정

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(
    optimizer=RMSprop(learning_rate=0.001, decay=1e-6),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# - 파일에서 이미지 데이터 읽어오는 방법

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
test_generator = test_datagen.flow_from_directory(
    test_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
# Out:
# Found 20001 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.

# %% [markdown]
# - callback 정의

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

model_path = 'best-cat-dog-v3.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %% [markdown]
# - 모델 실행

# %%
# 어느 파일에서 에러가 발생했는지 알아보는 코드
from PIL import Image
# img = Image.open(f'{train_dogs_dir}/11.jpg')
# plt.imshow(img);
import glob
try:
    for fname in glob.glob(f'{test_dogs_dir}/*.jpg'):
        img = Image.open(fname)
except:
    print(fname)

# %%
hist = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=100,
    steps_per_epoch=1000,       # 한번의 epoch에서 훈련에 사용할 batch의 갯수
    validation_steps=250,       # 한번의 epoch가 끝났을 때, 테스트에 사용되는 batch의 갯수
    verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.58430, saving model to best-cat-dog-v3.h5
# 1000/1000 - 72s - loss: 0.6451 - accuracy: 0.6428 - val_loss: 0.5843 - val_accuracy: 0.6854 - 72s/epoch - 72ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.58430 to 0.51668, saving model to best-cat-dog-v3.h5
# 1000/1000 - 70s - loss: 0.5349 - accuracy: 0.7366 - val_loss: 0.5167 - val_accuracy: 0.7356 - 70s/epoch - 70ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.51668 to 0.45976, saving model to best-cat-dog-v3.h5
# 1000/1000 - 70s - loss: 0.5013 - accuracy: 0.7613 - val_loss: 0.4598 - val_accuracy: 0.7840 - 70s/epoch - 70ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.45976 to 0.44662, saving model to best-cat-dog-v3.h5
# 1000/1000 - 70s - loss: 0.4696 - accuracy: 0.7841 - val_loss: 0.4466 - val_accuracy: 0.7928 - 70s/epoch - 70ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.44662 to 0.43592, saving model to best-cat-dog-v3.h5
# 1000/1000 - 70s - loss: 0.4559 - accuracy: 0.7930 - val_loss: 0.4359 - val_accuracy: 0.7978 - 70s/epoch - 70ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.43592 to 0.42918, saving model to best-cat-dog-v3.h5
# 1000/1000 - 70s - loss: 0.4472 - accuracy: 0.7991 - val_loss: 0.4292 - val_accuracy: 0.7964 - 70s/epoch - 70ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss did not improve from 0.42918
# 1000/1000 - 70s - loss: 0.4336 - accuracy: 0.8075 - val_loss: 0.4655 - val_accuracy: 0.8004 - 70s/epoch - 70ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss did not improve from 0.42918
# 1000/1000 - 69s - loss: 0.4251 - accuracy: 0.8141 - val_loss: 0.4397 - val_accuracy: 0.8030 - 69s/epoch - 69ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 0.42918
# 1000/1000 - 69s - loss: 0.4192 - accuracy: 0.8153 - val_loss: 0.4982 - val_accuracy: 0.7744 - 69s/epoch - 69ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.42918 to 0.39033, saving model to best-cat-dog-v3.h5
# 1000/1000 - 69s - loss: 0.4170 - accuracy: 0.8197 - val_loss: 0.3903 - val_accuracy: 0.8328 - 69s/epoch - 69ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 0.39033
# 1000/1000 - 69s - loss: 0.4149 - accuracy: 0.8216 - val_loss: 0.4283 - val_accuracy: 0.8244 - 69s/epoch - 69ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss did not improve from 0.39033
# 1000/1000 - 69s - loss: 0.4169 - accuracy: 0.8220 - val_loss: 0.4487 - val_accuracy: 0.8086 - 69s/epoch - 69ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.39033 to 0.38550, saving model to best-cat-dog-v3.h5
# 1000/1000 - 69s - loss: 0.4161 - accuracy: 0.8224 - val_loss: 0.3855 - val_accuracy: 0.8332 - 69s/epoch - 69ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.38550
# 1000/1000 - 69s - loss: 0.4119 - accuracy: 0.8238 - val_loss: 0.4373 - val_accuracy: 0.8012 - 69s/epoch - 69ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.38550
# 1000/1000 - 69s - loss: 0.4223 - accuracy: 0.8218 - val_loss: 0.4294 - val_accuracy: 0.8350 - 69s/epoch - 69ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss did not improve from 0.38550
# 1000/1000 - 69s - loss: 0.4274 - accuracy: 0.8217 - val_loss: 0.4401 - val_accuracy: 0.8092 - 69s/epoch - 69ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.38550
# 1000/1000 - 69s - loss: 0.4262 - accuracy: 0.8229 - val_loss: 0.4345 - val_accuracy: 0.8198 - 69s/epoch - 69ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 0.38550
# 1000/1000 - 69s - loss: 0.4272 - accuracy: 0.8213 - val_loss: 0.4875 - val_accuracy: 0.8020 - 69s/epoch - 69ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.38550
# 1000/1000 - 69s - loss: 0.4426 - accuracy: 0.8192 - val_loss: 0.4305 - val_accuracy: 0.8258 - 69s/epoch - 69ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.38550
# 1000/1000 - 69s - loss: 0.4359 - accuracy: 0.8180 - val_loss: 0.4422 - val_accuracy: 0.8206 - 69s/epoch - 69ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 0.38550
# 1000/1000 - 69s - loss: 0.4435 - accuracy: 0.8187 - val_loss: 0.5301 - val_accuracy: 0.7814 - 69s/epoch - 69ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.38550
# 1000/1000 - 69s - loss: 0.4441 - accuracy: 0.8084 - val_loss: 0.4570 - val_accuracy: 0.8076 - 69s/epoch - 69ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 0.38550
# 1000/1000 - 69s - loss: 0.4418 - accuracy: 0.8166 - val_loss: 0.5096 - val_accuracy: 0.7492 - 69s/epoch - 69ms/step

# %%
from tensorflow.keras.models import load_model
best_model = load_model(model_path)

# %% [markdown]
# - 테스트 이미지 분류

# %%
from google.colab import files

up = files.upload()
# Out:
#      <input type="file" id="files-ebdf6eb9-209d-4aec-9493-aed025a3c3ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ebdf6eb9-209d-4aec-9493-aed025a3c3ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat1.jpg to cat1.jpg
# Saving cat2.jpg to cat2.jpg
# Saving cat3.jpg to cat3.jpg
# Saving cat4.jpg to cat4.jpg
# Saving dog1.jpg to dog1.jpg
# Saving dog2.jpg to dog2.jpg
# Saving dog3.jpg to dog3.jpg
# Saving dog4.jpg to dog4.jpg

# %%
for fname in up.keys():
    img = cv2.imread(fname)[:,:,::-1]
    if sum(img.shape[:-1]) > 300:       # 150 x 150 보다 큰 이미지
        img = cv2.resize(img, dsize=(150,150), interpolation=cv2.INTER_AREA)
    else:
        img = cv2.resize(img, dsize=(150,150), interpolation=cv2.INTER_CUBIC)
    classes = best_model.predict(img.reshape(1,150,150,3))
    print(f"{classes[0,0]:.4f} {fname} is a {'dog' if classes[0,0] > 0.5 else 'cat'}")
# Out:
# 0.0000 cat1.jpg is a cat
# 0.0000 cat2.jpg is a cat
# 0.0000 cat3.jpg is a cat
# 0.2172 cat4.jpg is a cat
# 0.0000 dog1.jpg is a cat
# 0.0000 dog2.jpg is a cat
# 1.0000 dog3.jpg is a dog
# 1.0000 dog4.jpg is a dog

# %% [markdown]
# - 학습과정 시각화

# %%
import numpy as np
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
