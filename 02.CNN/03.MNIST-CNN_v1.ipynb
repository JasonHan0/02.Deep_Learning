# %% [markdown]
# # MNIST 손글씨 - CNN v1
# - 2 Conv2D layers
# - 1 Fully Connected Network layer
# - 1 Output layer

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
# X data: 0~1 사이의 값, 3차원 --> 4차원
X_train = X_train.reshape(-1,28,28,1) / 255.
X_test = X_test.reshape(-1,28,28,1) / 255.

# %%
# One-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의, 설정, 학습, 평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([ 
    Conv2D(32, kernel_size=(3,3), input_shape=(28,28,1), activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dense (Dense)               (None, 512)               18874880
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 18,898,826
# Trainable params: 18,898,826
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model_path = 'best-mnist-cnn-v1.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2, epochs=100, batch_size=200,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
# 240/240 [==============================] - ETA: 0s - loss: 0.1520 - accuracy: 0.9532
# Epoch 00001: val_loss improved from inf to 0.05589, saving model to best-mnist-cnn-v1.h5
# 240/240 [==============================] - 21s 22ms/step - loss: 0.1520 - accuracy: 0.9532 - val_loss: 0.0559 - val_accuracy: 0.9837
# Epoch 2/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0354 - accuracy: 0.9893
# Epoch 00002: val_loss improved from 0.05589 to 0.05312, saving model to best-mnist-cnn-v1.h5
# 240/240 [==============================] - 5s 21ms/step - loss: 0.0353 - accuracy: 0.9893 - val_loss: 0.0531 - val_accuracy: 0.9858
# Epoch 3/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 0.9945
# Epoch 00003: val_loss improved from 0.05312 to 0.04705, saving model to best-mnist-cnn-v1.h5
# 240/240 [==============================] - 5s 21ms/step - loss: 0.0177 - accuracy: 0.9946 - val_loss: 0.0470 - val_accuracy: 0.9868
# Epoch 4/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0104 - accuracy: 0.9966
# Epoch 00004: val_loss did not improve from 0.04705
# 240/240 [==============================] - 5s 19ms/step - loss: 0.0103 - accuracy: 0.9966 - val_loss: 0.0486 - val_accuracy: 0.9869
# Epoch 5/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9974
# Epoch 00005: val_loss did not improve from 0.04705
# 240/240 [==============================] - 4s 19ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 0.0572 - val_accuracy: 0.9862
# Epoch 6/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 0.9979
# Epoch 00006: val_loss did not improve from 0.04705
# 240/240 [==============================] - 4s 19ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.0472 - val_accuracy: 0.9874
# Epoch 7/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9981
# Epoch 00007: val_loss did not improve from 0.04705
# 240/240 [==============================] - 4s 19ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0544 - val_accuracy: 0.9872
# Epoch 8/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9990
# Epoch 00008: val_loss did not improve from 0.04705
# 240/240 [==============================] - 4s 19ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0517 - val_accuracy: 0.9893
# Epoch 9/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9993
# Epoch 00009: val_loss did not improve from 0.04705
# 240/240 [==============================] - 4s 19ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0614 - val_accuracy: 0.9890
# Epoch 10/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992
# Epoch 00010: val_loss did not improve from 0.04705
# 240/240 [==============================] - 4s 19ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0718 - val_accuracy: 0.9868
# Epoch 11/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9981
# Epoch 00011: val_loss did not improve from 0.04705
# 240/240 [==============================] - 4s 19ms/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.0642 - val_accuracy: 0.9854
# Epoch 12/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9978
# Epoch 00012: val_loss did not improve from 0.04705
# 240/240 [==============================] - 4s 19ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0574 - val_accuracy: 0.9887
# Epoch 13/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 0.9987
# Epoch 00013: val_loss did not improve from 0.04705
# 240/240 [==============================] - 4s 19ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0530 - val_accuracy: 0.9883

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0414 - accuracy: 0.9879
# [0.04144402593374252, 0.9879000186920166]
